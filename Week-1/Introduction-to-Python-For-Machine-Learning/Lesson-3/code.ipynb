# %%
import pandas as pd

# %%
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv")

# %%
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df["Element Code"].corr(df["Y2016"])
# Out:
# 0.02344399758496138

# %%
df["Element Code"].corr(df["Y2015"])
# Out:
# 0.02388919930163995

# %%
df["Element Code"].corr(df["Y2017"])
# Out:
# 0.024254007760045757

# %%
df["Element Code"].corr(df["Y2014"])
# Out:
# 0.024456819495221736

# %%
df2 = df[["Area","Y2017"]]
df2.groupby("Area").sum()
# Out:
#                                   Y2017
# Area
# Algeria                       325644.27
# Angola                        229159.57
# Benin                         124771.22
# Botswana                       22101.30
# Burkina Faso                  101855.07
# Cabo Verde                     14650.74
# Cameroon                      232030.43
# Central African Republic       29937.00
# Chad                           71594.68
# Comoros                           59.84
# Congo                          41181.68
# C�te d'Ivoire                 224599.01
# Djibouti                       22729.91
# Egypt                         866379.92
# Eswatini                       54343.33
# Ethiopia                      448683.76
# Ethiopia PDR                       0.00
# Gabon                          27979.64
# Gambia                         23154.18
# Ghana                         337599.06
# Guinea                         98138.87
# Guinea-Bissau                  19102.77
# ...

# %%
df.groupby("Element").sum()
# Out:
#                                         Area Code  \
# Element
# Domestic supply quantity                   708993
# Export Quantity                            599910
# Fat supply quantity (g/capita/day)         675050
# Feed                                       176272
# Food                                       663295
# Food supply (kcal/capita/day)              674057
# Food supply quantity (kg/capita/yr)        658446
# Import Quantity                            688174
# Losses                                     274353
# Other uses (non-food)                      235554
# Processing                                 271940
# Production                                 526751
# Protein supply quantity (g/capita/day)     675050
# Residuals                                  623271
# Seed                                       103537
# Stock Variation                            571566
# Total Population - Both sexes                6020
# ...

# %%
len(df["Area"].unique())
# Out:
# 49

# %%
x = df.groupby("Element").first()
x
# Out:
#                                         Area Code     Area  Item Code  \
# Element
# Domestic supply quantity                        4  Algeria       2501
# Export Quantity                                 4  Algeria       2905
# Fat supply quantity (g/capita/day)              4  Algeria       2901
# Feed                                            4  Algeria       2905
# Food                                            4  Algeria       2905
# Food supply (kcal/capita/day)                   4  Algeria       2901
# Food supply quantity (kg/capita/yr)             4  Algeria       2905
# Import Quantity                                 4  Algeria       2905
# Losses                                          4  Algeria       2905
# Other uses (non-food)                           4  Algeria       2905
# Processing                                      4  Algeria       2905
# Production                                      4  Algeria       2905
# ...

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
array[:1][1:]
# Out:
# []

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\HP\Documents\Hamoye\Week-1\Introduction-to-Python-For-Machine-Learning\Lesson-3\code.ipynb Cell 14 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Hamoye/Week-1/Introduction-to-Python-For-Machine-Learning/Lesson-3/code.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> my_tuppy = (1,2,5,8)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Hamoye/Week-1/Introduction-to-Python-For-Machine-Learning/Lesson-3/code.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv")

# %%
df2 = df[["Y2017", "Area"]]

# %%
df.groupby("Item").first().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\HP\Documents\Hamoye\Week-1\Introduction-to-Python-For-Machine-Learning\Lesson-3\code.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/Hamoye/Week-1/Introduction-to-Python-For-Machine-Learning/Lesson-3/code.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> df.groupby("Item == Wine").first().sum()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
# ...

# %%
grouped_data
# Out:
# Empty DataFrame
# Columns: [Area Code, Area, Item Code, Item, Element Code, Unit, Y2014, Y2015, Y2016, Y2017, Y2018]
# Index: []
